# %%
import requests
from bs4 import BeautifulSoup

r=requests.get("https://www.century21.com/real-estate/rocksprings-tx/LCTXROCKSPRINGS/")
c=r.content

soup = BeautifulSoup(c,"html.parser")
all =soup.find_all("div",{"class":"infinite-item"})
#print(all)

#print(soup.find_all("div",{"class":"pdp"}))

all[0].find("a",{"class":"listing-price"}).text.replace("\n","").replace(" ","")
# Out:
# '$290,000'

# %%
l=[]
for item in all:
    d={}
    try:
        d["Price"]=item.find("a",{"class":"listing-price"}).text.replace("\n","").replace(" ","")
    except:
        d["Price"]=None
    try:
        d["Address"]=item.find_all("div",{"class" :"property-address-info"})[0].text.replace("\n","").replace("               ","").replace("         ","  ")
    except:
        d["Address"]=None
    try:
        d["Beds"]=item.find("div",{"class" :"property-beds"}).find("strong").text
    except:
        d["Beds"]=None
    try:
        d["Baths"]=item.find("div",{"class" :"property-baths"}).find("strong").text
    except:
        d["Baths"]=None
    try:
        d["Area"]=item.find("div",{"class" :"property-sqft"}).find("strong").text
    except:
        d["Area"]=None    
        l.append(d)

# %%
l
# Out:
# [{'Price': '$99,450',
#   'Address': '425 425 Sd 63530  RockSprings TX 78880  ',
#   'Beds': None,
#   'Baths': None,
#   'Area': None},
#  {'Price': '$3,625,000',
#   'Address': '00 Cr 903  Rocksprings TX 78880  ',
#   'Beds': None,
#   'Baths': None,
#   'Area': None},
#  {'Price': '$229,961',
#   'Address': 'County Road 550  Rocksprings TX 78880  ',
#   'Beds': None,
#   'Baths': None,
#   'Area': None},
#  {'Price': '$75,000',
#   'Address': 'Lot 41 Pinion Ranch  Rocksprings TX 78880  ',
#   'Beds': None,
#   'Baths': None,
#   'Area': None},
#  {'Price': '$2,400,000',
#   'Address': '7600 Cr 450  Rocksprings TX 78880  ',
#   'Beds': '4',
#   'Baths': '3',
#   'Area': None},
#  {'Price': '$3,625,000',
#   'Address': '2132 Rr 2995  Rocksprings TX 78880  ',
#   'Beds': None,
#   'Baths': None,
#   'Area': None},
#  {'Price': '$3,285,565',
#   'Address': '00 County Road 440  Rocksprings TX 78880  ',
#   'Beds': None,
#   'Baths': None,
#   'Area': None},
#  {'Price': '$3,285,565',
# ...

# %%
import pandas
df=pandas.DataFrame(l)

# %%
df
# Out:
#          Price                                      Address  Beds Baths  Area
# 0      $99,450     425 425 Sd 63530  RockSprings TX 78880    None  None  None
# 1   $3,625,000            00 Cr 903  Rocksprings TX 78880    None  None  None
# 2     $229,961      County Road 550  Rocksprings TX 78880    None  None  None
# 3      $75,000  Lot 41 Pinion Ranch  Rocksprings TX 78880    None  None  None
# 4   $2,400,000          7600 Cr 450  Rocksprings TX 78880       4     3  None
# 5   $3,625,000         2132 Rr 2995  Rocksprings TX 78880    None  None  None
# 6   $3,285,565   00 County Road 440  Rocksprings TX 78880    None  None  None
# 7   $3,285,565               Cr 440  Rocksprings TX 78880    None  None  None
# 8   $3,285,565               Cr 440  Rocksprings TX 78880    None  None  None
# 9   $1,127,000              0 Other  Rocksprings TX 78880    None  None  None
# 10  $1,127,000                Other  Rocksprings TX 78880    None  None  None
# ...

# %%
df.to_csv("Output.csv")

# %%
r=requests.get("https://www.century21.com/real-estate/rocksprings-tx/LCTXROCKSPRINGS/?pdp=REN012775723")
c=r.content

soup = BeautifulSoup(c,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-usagetrack-config='{"clickDefault": "ga-event", "viewDefault": "ga-event", "viewOnReady": true}' lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="minimum-scale=1.0, width=device-width, maximum-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="Rocksprings Real Estate | Find Houses &amp; Homes for Sale in Rocksprings, TX" name="title"/>
#   <meta content="Search Rocksprings real estate property listings to find homes for sale in Rocksprings, TX. Browse houses for sale in Rocksprings today!" name="description">
# ...
